# %% [markdown]
# <a href="https://colab.research.google.com/github/bibicrr/bibicrr/blob/main/Respuestas_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Default title text
import pandas as pd
import os.path
import plotly.express as px
import numpy as np
import datetime
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
arch_dc1 = pd.read_excel("/content/drive/MyDrive/Copy of Shopify Customers_Total Spent_First order Date.xlsx")

# %%
xls_5= pd.ExcelFile("/content/drive/MyDrive/Copy of Newsletter-after-08-01-2019.xlsx")

# %%
sheets_5= xls_5.sheet_names
sheets_5
# Out:
# ['Newsletter-after-08-01-2019']

# %%
df_Newsletter_af_08_19=pd.read_excel("/content/drive/MyDrive/Copy of Newsletter-after-08-01-2019.xlsx", sheet_name='Newsletter-after-08-01-2019', header=[0])
df_Newsletter_af_08_19.head()
# Out:
#                       Email          Date Added
# 0          ddnftc@gmail.com 2023-11-15 14:04:04
# 1         ann7162@gmail.com 2023-11-15 14:04:04
# 2  howcanwechange@gmail.com 2023-11-15 14:04:04
# 3    jahalia.imes@yahoo.com 2023-11-15 14:04:04
# 4     kathleen_hall@mac.com 2023-11-15 14:04:04

# %%
len(df_Newsletter_af_08_19)
# Out:
# 861413

# %%
df_Newslatter_reduc=df_Newsletter_af_08_19.drop_duplicates(['Email'])

# %%
len(df_Newslatter_reduc)
# Out:
# 861073

# %%
xls_6= pd.ExcelFile("/content/drive/MyDrive/Copy of FMP Trial Accounts_All Time.xlsx")

# %%
sheets_6= xls_6.sheet_names
sheets_6
# Out:
# ['trials_created_on_october',
#  'trials_expired_on_october',
#  'trials_on_2016',
#  'trials_on_2017',
#  'trials_on_2018',
#  'trials_on_2019',
#  'trials_on_2020',
#  'trials_on_2021',
#  'trials_on_2022',
#  'trials_on_2023']

# %%
df_FMP_23 = pd.read_excel('/content/drive/MyDrive/Copy of FMP Trial Accounts_All Time.xlsx', sheet_name='trials_on_2023')
df_FMP_23.head()
# Out:
#                                  Email Trial Start Date
# 0                    munchee30@aol.com       2023-01-01
# 1  zxhns6y5t2@privaterelay.appleid.com       2023-01-01
# 2                  tanya5223@gmail.com       2023-01-01
# 3  dmsdann@yahoo.com (deleted account)       2023-01-01
# 4               chelzinga942@yahoo.com       2023-01-01

# %%
xls_7= pd.ExcelFile("/content/drive/MyDrive/Copy of Shopify Customers_Total Spent_First order Date.xlsx")
sheets_7= xls_7.sheet_names
sheets_7
# Out:
# ['Shopify Customers']

# %%
df_Shopy_Purc = pd.read_excel('/content/drive/MyDrive/Copy of Shopify Customers_Total Spent_First order Date.xlsx', sheet_name='Shopify Customers')
df_Shopy_Purc.head()
# Out:
#      customer_id          full_name                      email  \
# 0  5517326942389  Pauline Doan Doan         pldoan49@gmail.com
# 1  5517663142069  Susan Tyler Tyler      tylersusan2@gmail.com
# 2  5517702004917      Andrew Rogers    andrew@upbeetbrands.com
# 3  5518133788853  Nancy Rader Rader     momrader7680@gmail.com
# 4  5518343372981   Millicent McPhee  millicentmcphee@gmail.com
#
#    total_number_of_orders  total_amount_spent           first_order_date
# 0                       3               49.29  2021-08-26T16:20:09-04:00
# 1                       1               39.55  2021-08-26T19:36:01-04:00
# 2                       1               19.01  2021-08-26T19:58:22-04:00
# 3                       1               16.01  2021-08-27T00:49:55-04:00
# 4                       1               39.54  2021-08-27T04:13:11-04:00

# %%
df_Shopy_Purc.columns=df_Shopy_Purc.columns.str.replace('email','Email')
df_Shopy_Purc.head()
# Out:
#      customer_id          full_name                      Email  \
# 0  5517326942389  Pauline Doan Doan         pldoan49@gmail.com
# 1  5517663142069  Susan Tyler Tyler      tylersusan2@gmail.com
# 2  5517702004917      Andrew Rogers    andrew@upbeetbrands.com
# 3  5518133788853  Nancy Rader Rader     momrader7680@gmail.com
# 4  5518343372981   Millicent McPhee  millicentmcphee@gmail.com
#
#    total_number_of_orders  total_amount_spent           first_order_date
# 0                       3               49.29  2021-08-26T16:20:09-04:00
# 1                       1               39.55  2021-08-26T19:36:01-04:00
# 2                       1               19.01  2021-08-26T19:58:22-04:00
# 3                       1               16.01  2021-08-27T00:49:55-04:00
# 4                       1               39.54  2021-08-27T04:13:11-04:00

# %%
len(df_Shopy_Purc)
# Out:
# 23457

# %%
df_shopi_FMP_23 =pd.merge(df_FMP_23,df_Shopy_Purc,on="Email")
df_shopi_FMP_23.head()
# Out:
#                        Email Trial Start Date    customer_id        full_name  \
# 0         mlcn9742@gmail.com       2023-01-01  6721283653881      mary conner
# 1         kpfawley@gmail.com       2023-01-01  6633473966329     Karen Fawley
# 2      rwilkinsoncpa@aol.com       2023-01-01  6514981601529   Roma Wilkinson
# 3  stephaniebrush1@gmail.com       2023-01-01  6907818180857  Stephanie Brush
# 4      tyzipperer3@gmail.com       2023-01-01  6597244911865   Tyler Zipperer
#
#    total_number_of_orders  total_amount_spent           first_order_date
# 0                       1               18.30  2023-03-09T12:04:22-05:00
# 1                       1               19.44  2023-01-01T06:12:39-05:00
# 2                       2               39.48  2022-10-15T12:51:42-04:00
# 3                       1               19.30  2023-08-24T15:26:32-04:00
# 4                       1               18.14  2023-01-01T18:09:05-05:00

# %%
df_shopi_FMP_23['total_amount_spent'].sum()
# Out:
# 38343.66

# %%
xls_8= pd.ExcelFile("/content/drive/MyDrive/Copy of Subscriber lists.xlsx")
sheets_8= xls_8.sheet_names
sheets_8
# Out:
# ['New Unbounce subs',
#  'New FBIG subs',
#  'New Plantstrong subs',
#  'CC Purchases from 112 - 1114',
#  'Trialers and Purchasers from Dr',
#  'Shopify customers & total spent',
#  'CC students ove all time']

# %%
df_Subs_CC = pd.read_excel('/content/drive/MyDrive/Copy of Subscriber lists.xlsx', sheet_name='Shopify Customers')
df_Shopy_Purc.head()

# %%
df_CC_Purchases_from_112_1114 = pd.read_excel("/content/drive/MyDrive/Copy of Subscriber lists.xlsx", sheet_name='CC Purchases from 112 - 1114')
df_CC_Purchases_from_112_1114.columns=df_CC_Purchases_from_112_1114.columns.str.replace('email','Email')
df_CC_Purchases_from_112_1114.head()
# Out:
#                       Email first_name  last_name          Sales Date  \
# 0  eveannkauffman@gmail.com     Eveann   Kauffman 2023-11-02 12:23:26
# 1        billwig1@yahoo.com    William     Wigton 2023-11-02 13:21:29
# 2           jdwf111@aol.com      JoAnn     DeWind 2023-11-02 13:24:55
# 3          jdshopper@me.com      James     Durden 2023-11-02 13:25:39
# 4      danadf1015@gmail.com       Dana  Farrakhan 2023-11-02 13:26:30
#
#                                              product   Sales Discount Code  \
# 0               Forks Over Knives - 30-day extension   39.99           NaN
# 1  Forks Over Knives - Forks Over Knives Ultimate...  149.00           NaN
# 2  Forks Over Knives - Forks Over Knives Ultimate...  149.00           NaN
# 3  Forks Over Knives - Forks Over Knives Ultimate...  149.00           NaN
# 4                                         Gift Cards   59.00           NaN
#
#   Discount Description
# 0                  NaN
# 1                  NaN
# ...

# %%
df_Purc_112_1114 =pd.merge(df_CC_Purchases_from_112_1114,df_Shopy_Purc,on="Email")
df_Purc_112_1114.head()
# Out:
#                   Email first_name       last_name          Sales Date  \
# 0       jdwf111@aol.com      JoAnn          DeWind 2023-11-02 13:24:55
# 1      jdshopper@me.com      James          Durden 2023-11-02 13:25:39
# 2  rlmcmathis@gmail.com      Roger          Mathis 2023-11-02 14:21:50
# 3    icjknoll@yahoo.com    Ingrid   Tabuntschikow  2023-11-02 14:41:54
# 4     langstaff@cox.net  Katherine          McLeod 2023-11-02 16:16:05
#
#                                              product  Sales Discount Code  \
# 0  Forks Over Knives - Forks Over Knives Ultimate...  149.0           NaN
# 1  Forks Over Knives - Forks Over Knives Ultimate...  149.0           NaN
# 2  Forks Over Knives - Forks Over Knives Ultimate...  149.0           NaN
# 3  Forks Over Knives - Forks Over Knives Ultimate...  149.0           NaN
# 4  Forks Over Knives - Forks Over Knives Ultimate...  149.0           NaN
#
#   Discount Description    customer_id             full_name  \
# ...

# %%
df_Purc_112_1114['total_amount_spent'].sum()
# Out:
# 875.8999999999999
